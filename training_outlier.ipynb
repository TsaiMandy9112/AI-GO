# %%
import pandas as pd

df = pd.read_csv('./training_with_all_temp.csv')

# %%
df
# Out:
#       Unnamed: 0        ID         lon        lat  house_age  \
# 0              0      TR-1  121.547608  25.022469  32.583333
# 1              1      TR-2  121.502124  25.019127  24.166667
# 2              2      TR-3  120.365799  22.640966   6.166667
# 3              3      TR-4  121.462402  25.058664   8.833333
# 4              4      TR-5  121.469444  25.023585  11.000000
# ...          ...       ...         ...        ...        ...
# 2470       11746  TR-11747  121.298684  24.935576  28.333333
# 2471       11747  TR-11748  120.973622  24.795109  29.250000
# 2472       11748  TR-11749  121.660968  25.072204  22.833333
# 2473       11749  TR-11750  121.453610  24.982953  25.083333
# 2474       11750  TR-11751  121.497284  25.057133   2.250000
#
#       residence_housing  congregate_housing  commercial_use  industrial_use  \
# 0                     1                   0               0               0
# 1                     1                   0               0               0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'lon', 'lat', 'house_age',
#        'residence_housing', 'congregate_housing', 'commercial_use',
#        'industrial_use', 'apartment', 'building_low', 'building_high', 'RB',
#        'RC', 'SC', 'land_area', 'building_area', 'main_building_area',
#        'balcony_area', 'auxiliary_area', 'floor', 'total_floor',
#        'parking_area', 'parking_number', 'unit_price', 'd_park',
#        'park_distance_less_than_500m', 'd_dep', 'dep_distance_less_than_500m',
#        'd_tmarket', 'tmarket_distance_less_than_500m', 'd_bad',
#        'bad_distance_less_than_500m', 'd_bus', 'bus_distance_less_than_500m',
#        'd_bike', 'bike_distance_less_than_500m', 'd_mrt',
#        'mrt_distance_less_than_500m', 'd_train',
#        'train_distance_less_than_500m', 'convenient', 'd_fin',
#        'fin_distance_less_than_500m', 'd_post', 'post_distance_less_than_500m',
#        'd_ho', 'ho_distance_less_than_500m', 'd_store',
# ...

# %%
df2 = pd.DataFrame(df['unit_price'])
df2
# Out:
#        unit_price
# 0        4.627714
# 1        1.887258
# 2        1.489072
# 3        2.051217
# 4        3.269198
# ...           ...
# 11746    0.903505
# 11747    1.044041
# 11748    2.144908
# 11749    2.285444
# 11750    2.660207
#
# [11751 rows x 1 columns]

# %%
# 删除大於10的行
df2.drop(df2[df2['unit_price'] > 10].index, inplace=True)

# %%
df2
# Out:
#        unit_price
# 0        4.627714
# 1        1.887258
# 2        1.489072
# 3        2.051217
# 4        3.269198
# ...           ...
# 11746    0.903505
# 11747    1.044041
# 11748    2.144908
# 11749    2.285444
# 11750    2.660207
#
# [11751 rows x 1 columns]
